# %%
import pandas as pd
import numpy as np

# %%
bball_data = pd.DataFrame.from_csv('bball.csv')
steph= bball_data.loc[bball_data['Tm'] == 'GSW']
pg = bball_data.where(bball_data['Pos'] == 'PG').where(bball_data['MP'] > 15.0).dropna((0,1), 'all').drop(['Pos'])
pg
# Out:
#                                 Player Pos   Age   Tm     G    GS    MP    FG  \
# Rk
# 19     Giannis Antetokounmpo\antetgi01  PG  21.0  MIL  80.0  79.0  35.3   6.4
# 27             D.J. Augustin\augusdj01  PG  28.0  TOT  62.0   0.0  19.0   2.4
# 27             D.J. Augustin\augusdj01  PG  28.0  OKC  34.0   0.0  15.3   1.4
# 27             D.J. Augustin\augusdj01  PG  28.0  DEN  28.0   0.0  23.5   3.6
# 32                J.J. Barea\bareajo01  PG  31.0  DAL  74.0  16.0  22.5   4.3
# 46          Patrick Beverley\beverpa01  PG  27.0  HOU  71.0  63.0  28.7   3.6
# 51               Steve Blake\blakest01  PG  35.0  DET  58.0   2.0  17.0   1.6
# 52              Eric Bledsoe\bledser01  PG  26.0  PHO  31.0  31.0  34.2   7.2
# 62              Aaron Brooks\brookaa01  PG  31.0  CHI  69.0   0.0  16.1   2.7
# 69                Trey Burke\burketr01  PG  23.0  UTA  64.0   0.0  21.3   4.1
# 75             Jose Calderon\caldejo01  PG  34.0  NYK  72.0  72.0  28.1   2.9
# ...
